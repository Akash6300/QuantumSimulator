# %%
from single_qubit_gates import *

# %%
qc=QCircuit(1)
qc.h(0)
qc.z(0)
qc.h(0)
counts=qc.measure(1000)
print(counts)
# Out:
# {'1': 1000}

# %%
visualize_counts(counts,color='c')

# %%
qc=QCircuit(2)
qc.h(0)
qc.z(0)
qc.h(0)
qc.h(1)
counts=qc.measure(100)
print(counts)
# Out:
# {'11': 54, '10': 46}

# %%
visualize_counts(counts,color='b')

# %%
qc=QCircuit(10)
qc.h(0)
qc.z(0)
qc.h(0)
qc.h(9)
qc.z(9)
qc.h(9)
qc.h(4)
qc.h(7)
counts=qc.measure(1000)
print(counts)
# Out:
# {'1000000101': 275, '1000100001': 251, '1000100101': 242, '1000000001': 232}

# %%
visualize_counts(counts,color='c')

# %%
qc=QCircuit(15)
qc.h(0)
qc.z(0)
qc.h(0)
qc.x(3)
qc.x(8)
qc.h(10)
qc.h(14)
qc.z(10)
qc.x(14)
counts=qc.measure(1000)
print(counts)
# Out:
# {'100100001010000': 268, '100100001000000': 249, '100100001010001': 243, '100100001000001': 240}

# %%
visualize_counts(counts,color='purple')
